# %%
# !wget https://ftp.gramene.org/maize/release-5/gff3/zea_maysb73v3/Zea_maysb73v3.AGPv3.gff3.gz
# Out:
# --2026-04-09 13:28:36--  https://ftp.gramene.org/maize/release-5/gff3/zea_maysb73v3/Zea_maysb73v3.AGPv3.gff3.gz
# Resolving ftp.gramene.org (ftp.gramene.org)... 143.48.220.80
# Connecting to ftp.gramene.org (ftp.gramene.org)|143.48.220.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8040973 (7.7M) [application/x-gzip]
# Saving to: ‘Zea_maysb73v3.AGPv3.gff3.gz’
#
# Zea_maysb73v3.AGPv3 100%[===================>]   7.67M  1.80MB/s    in 5.4s
#
# 2026-04-09 13:28:42 (1.42 MB/s) - ‘Zea_maysb73v3.AGPv3.gff3.gz’ saved [8040973/8040973]
